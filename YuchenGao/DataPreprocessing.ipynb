# %%
import pandas as pd
import os

# %%
capture_path = "D:\SFU\\733-Lab\project\IoTScenarios"
str1 = "\conn01.log.labeled"
df_c = pd.read_table(filepath_or_buffer=capture_path+str1, skiprows=8, nrows=1000000)
df_c.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_c.drop(df_c.tail(1).index,inplace=True)

display(df_c)
# Out:
#                   ts                 uid        id.orig_h  id.orig_p  \
# 0       1.525880e+09  CH98aB3s1kJeq6SFOc  192.168.100.103      56305
# 1       1.525880e+09   C3GBTkINvXNjVGtN5  192.168.100.103      41101
# 2       1.525880e+09   CDe43c1PtgynajGI6  192.168.100.103      60905
# 3       1.525880e+09  CJaDcG3MZzvf1YVYI4  192.168.100.103      44301
# 4       1.525880e+09  CMBrup3BLXivSp4Avc  192.168.100.103      50244
# ...              ...                 ...              ...        ...
# 999994  1.526279e+09   Clo41Gu4KUuDEhdBc  192.168.100.103      35020
# 999995  1.526279e+09   CnyAEl4EDe2uIkFQI  192.168.100.103      43763
# 999996  1.526279e+09  CUkKne228rscXWclRf  192.168.100.103      53921
# 999997  1.526279e+09  CM5aZJ1y1Zy76aZWvg  192.168.100.103      43763
# 999998  1.526279e+09  CUEVsQ1IPF8Bxy5vT6  192.168.100.103      34609
#
#               id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0         63.150.16.171         23   tcp       -         -          -  ...
# 1          111.40.23.49         23   tcp       -         -          -  ...
# 2       131.174.215.147         23   tcp       -  2.998796          0  ...
# 3           91.42.47.63         23   tcp       -         -          -  ...
# 4       120.210.108.200         23   tcp       -         -          -  ...
# ...                 ...        ...   ...     ...       ...        ...  ...
# 999994    118.98.124.31       8080   tcp       -         -          -  ...
# 999995   206.133.81.169      11038   udp       -         -          -  ...
# 999996  179.233.115.201         23   tcp       -         -          -  ...
# 999997  108.162.177.234       8101   udp       -         -          -  ...
# 999998  157.248.158.157         23   tcp       -         -          -  ...
#
#        conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0              S0          -          -            0        S         1
# 1              S0          -          -            0        S         1
# 2              S0          -          -            0        S         3
# 3              S0          -          -            0        S         1
# 4              S0          -          -            0        S         1
# ...           ...        ...        ...          ...      ...       ...
# 999994         S0          -          -            0        S         1
# 999995         S0          -          -            0        D         1
# 999996         S0          -          -            0        S         1
# 999997         S0          -          -            0        D         1
# 999998         S0          -          -            0        S         1
#
#         orig_ip_bytes  resp_pkts  resp_ip_bytes  \
# 0                  60          0              0
# 1                  60          0              0
# 2                 180          0              0
# 3                  60          0              0
# 4                  60          0              0
# ...               ...        ...            ...
# 999994             60          0              0
# 999995             40          0              0
# 999996             60          0              0
# 999997             40          0              0
# 999998             60          0              0
#
#                                                   label
# 0       (empty)   Malicious   PartOfAHorizontalPortScan
# 1       (empty)   Malicious   PartOfAHorizontalPortScan
# 2       (empty)   Malicious   PartOfAHorizontalPortScan
# 3       (empty)   Malicious   PartOfAHorizontalPortScan
# 4       (empty)   Malicious   PartOfAHorizontalPortScan
# ...                                                 ...
# 999994  (empty)   Malicious   PartOfAHorizontalPortScan
# 999995                             (empty)   Benign   -
# 999996  (empty)   Malicious   PartOfAHorizontalPortScan
# 999997                             (empty)   Benign   -
# 999998  (empty)   Malicious   PartOfAHorizontalPortScan
#
# [999999 rows x 21 columns]

# %%
for i in range(2,61):
    str_i = str(i)
    i = str_i.zfill(2)
    path = capture_path + "\conn" + i + ".log.labeled"
    if os.path.exists(path):
        df = pd.read_table(filepath_or_buffer=path, skiprows=8, nrows=1000000)
        df.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
        df.drop(df.tail(1).index,inplace=True)
        df_c = pd.concat([df_c, df])
        
#display(df_c)
# Out:
# C:\Users\GaoYuchen\AppData\Local\Temp\ipykernel_44472\3595098022.py:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(filepath_or_buffer=path, skiprows=8, nrows=1000000)

# %%
df_c = df_c.drop(columns=['ts','uid','id.orig_h','id.orig_p','id.resp_h','id.resp_p',
                               'local_orig','local_resp','history','service'])

# %%
df_c.loc[(df_c.label == '-   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
df_c.loc[(df_c.label == '(empty)   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
df_c.loc[(df_c.label == '-   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '(empty)   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '-   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '(empty)   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   Malicious   DDoS'), 'label'] = 'DDoS'
df_c.loc[(df_c.label == '-   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '-   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '(empty)   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '-   Malicious   C&C-FileDownload'), 'label'] = 'C&C-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Torii'), 'label'] = 'C&C-Torii'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat-FileDownload'), 'label'] = 'C&C-HeartBeat-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   FileDownload'), 'label'] = 'FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Mirai'), 'label'] = 'C&C-Mirai'
df_c.loc[(df_c.label == '-   Malicious   Okiru-Attack'), 'label'] = 'Okiru-Attack'

# %%
df_c = df_c[(df_c['label'] == 'PartOfAHorizontalPortScan') | (df_c['label'] == 'Okiru') 
            | (df_c['label'] == 'Benign') | (df_c['label'] == 'DDoS')]
df_c['label'].value_counts()
# Out:
# PartOfAHorizontalPortScan    7459214
# Okiru                        2626252
# Benign                       1829115
# DDoS                         1263023
# Name: label, dtype: int64

# %%
df_POAHPS = df_c[df_c['label'] == 'PartOfAHorizontalPortScan'].sample(n=100000)
df_Okiru = df_c[df_c['label'] == 'Okiru'].sample(n=100000)
df_Benign = df_c[df_c['label'] == 'Benign'].sample(n=100000)
df_DDos = df_c[df_c['label'] == 'DDoS'].sample(n=100000)

df_c = pd.concat([df_POAHPS, df_Okiru, df_Benign, df_DDos])

df_c['label'].value_counts()
# Out:
# PartOfAHorizontalPortScan    100000
# Okiru                        100000
# Benign                       100000
# DDoS                         100000
# Name: label, dtype: int64

# %%
df_c = pd.get_dummies(df_c, columns=['proto'])
df_c = pd.get_dummies(df_c, columns=['conn_state'])

# %%
df_c['duration'] = df_c['duration'].str.replace('-','0')
df_c['orig_bytes'] = df_c['orig_bytes'].str.replace('-','0')
df_c['resp_bytes'] = df_c['resp_bytes'].str.replace('-','0')

display(df_c)
# Out:
#        duration orig_bytes resp_bytes  missed_bytes  orig_pkts  orig_ip_bytes  \
# 954088      NaN        NaN        NaN           0.0        2.0           80.0
# 321061        0          0          0           0.0        1.0           40.0
# 9653        NaN        NaN        NaN           0.0        2.0          120.0
# 315841      NaN        NaN        NaN           0.0        6.0          360.0
# 772571      NaN        NaN        NaN           0.0        4.0          160.0
# ...         ...        ...        ...           ...        ...            ...
# 906056      NaN        NaN        NaN           0.0        2.0           80.0
# 237492        0          0          0           0.0        0.0            0.0
# 659883      NaN        NaN        NaN           0.0        2.0           80.0
# 775297        0          0          0           0.0        0.0            0.0
# 254331        0          0          0           0.0        0.0            0.0
#
#         resp_pkts  resp_ip_bytes                      label  proto_icmp  ...  \
# 954088        0.0            0.0  PartOfAHorizontalPortScan           0  ...
# 321061        0.0            0.0  PartOfAHorizontalPortScan           0  ...
# 9653          0.0            0.0  PartOfAHorizontalPortScan           0  ...
# 315841        0.0            0.0  PartOfAHorizontalPortScan           0  ...
# 772571        0.0            0.0  PartOfAHorizontalPortScan           0  ...
# ...           ...            ...                        ...         ...  ...
# 906056        0.0            0.0                       DDoS           0  ...
# 237492        0.0            0.0                       DDoS           0  ...
# 659883        0.0            0.0                       DDoS           0  ...
# 775297        0.0            0.0                       DDoS           0  ...
# 254331        0.0            0.0                       DDoS           0  ...
#
#         conn_state_RSTOS0  conn_state_RSTR  conn_state_RSTRH  conn_state_S0  \
# 954088                  0                0                 0              1
# 321061                  0                0                 0              1
# 9653                    0                0                 0              1
# 315841                  0                0                 0              1
# 772571                  0                0                 0              1
# ...                   ...              ...               ...            ...
# 906056                  0                0                 0              1
# 237492                  0                0                 0              0
# 659883                  0                0                 0              1
# 775297                  0                0                 0              0
# 254331                  0                0                 0              0
#
#         conn_state_S1  conn_state_S2  conn_state_S3  conn_state_SF  \
# 954088              0              0              0              0
# 321061              0              0              0              0
# 9653                0              0              0              0
# 315841              0              0              0              0
# 772571              0              0              0              0
# ...               ...            ...            ...            ...
# 906056              0              0              0              0
# 237492              0              0              0              0
# 659883              0              0              0              0
# 775297              0              0              0              0
# 254331              0              0              0              0
#
#         conn_state_SH  conn_state_SHR
# 954088              0               0
# 321061              0               0
# 9653                0               0
# 315841              0               0
# 772571              0               0
# ...               ...             ...
# 906056              0               0
# 237492              0               0
# 659883              0               0
# 775297              0               0
# 254331              0               0
#
# [400000 rows x 25 columns]

# %%
df_c.fillna(-1,inplace=True)
df_c.isna().sum()
# Out:
# duration             0
# orig_bytes           0
# resp_bytes           0
# missed_bytes         0
# orig_pkts            0
# orig_ip_bytes        0
# resp_pkts            0
# resp_ip_bytes        0
# label                0
# proto_icmp           0
# proto_tcp            0
# proto_udp            0
# conn_state_OTH       0
# conn_state_REJ       0
# conn_state_RSTO      0
# conn_state_RSTOS0    0
# conn_state_RSTR      0
# conn_state_RSTRH     0
# conn_state_S0        0
# conn_state_S1        0
# conn_state_S2        0
# conn_state_S3        0
# conn_state_SF        0
# conn_state_SH        0
# conn_state_SHR       0
# dtype: int64

# %%
print(df_c.columns.tolist())
# Out:
# ['duration', 'orig_bytes', 'resp_bytes', 'missed_bytes', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes', 'label', 'proto_icmp', 'proto_tcp', 'proto_udp', 'conn_state_OTH', 'conn_state_REJ', 'conn_state_RSTO', 'conn_state_RSTOS0', 'conn_state_RSTR', 'conn_state_RSTRH', 'conn_state_S0', 'conn_state_S1', 'conn_state_S2', 'conn_state_S3', 'conn_state_SF', 'conn_state_SH', 'conn_state_SHR']

# %%
df_c.to_csv('D:\SFU\\733-Lab\project\IoTScenarios\iot23_combined.csv', index = None)

# %%
pd.set_option('display.max_columns', None)

# %%
display(df_c)
# Out:
#        duration orig_bytes resp_bytes  missed_bytes  orig_pkts  orig_ip_bytes  \
# 954088       -1         -1         -1           0.0        2.0           80.0
# 321061        0          0          0           0.0        1.0           40.0
# 9653         -1         -1         -1           0.0        2.0          120.0
# 315841       -1         -1         -1           0.0        6.0          360.0
# 772571       -1         -1         -1           0.0        4.0          160.0
# ...         ...        ...        ...           ...        ...            ...
# 906056       -1         -1         -1           0.0        2.0           80.0
# 237492        0          0          0           0.0        0.0            0.0
# 659883       -1         -1         -1           0.0        2.0           80.0
# 775297        0          0          0           0.0        0.0            0.0
# 254331        0          0          0           0.0        0.0            0.0
#
#         resp_pkts  resp_ip_bytes                      label  proto_icmp  \
# 954088        0.0            0.0  PartOfAHorizontalPortScan           0
# 321061        0.0            0.0  PartOfAHorizontalPortScan           0
# 9653          0.0            0.0  PartOfAHorizontalPortScan           0
# 315841        0.0            0.0  PartOfAHorizontalPortScan           0
# 772571        0.0            0.0  PartOfAHorizontalPortScan           0
# ...           ...            ...                        ...         ...
# 906056        0.0            0.0                       DDoS           0
# 237492        0.0            0.0                       DDoS           0
# 659883        0.0            0.0                       DDoS           0
# 775297        0.0            0.0                       DDoS           0
# 254331        0.0            0.0                       DDoS           0
#
#         proto_tcp  proto_udp  conn_state_OTH  conn_state_REJ  conn_state_RSTO  \
# 954088          1          0               0               0                0
# 321061          1          0               0               0                0
# 9653            1          0               0               0                0
# 315841          1          0               0               0                0
# 772571          1          0               0               0                0
# ...           ...        ...             ...             ...              ...
# 906056          1          0               0               0                0
# 237492          1          0               1               0                0
# 659883          1          0               0               0                0
# 775297          1          0               1               0                0
# 254331          1          0               1               0                0
#
#         conn_state_RSTOS0  conn_state_RSTR  conn_state_RSTRH  conn_state_S0  \
# 954088                  0                0                 0              1
# 321061                  0                0                 0              1
# 9653                    0                0                 0              1
# 315841                  0                0                 0              1
# 772571                  0                0                 0              1
# ...                   ...              ...               ...            ...
# 906056                  0                0                 0              1
# 237492                  0                0                 0              0
# 659883                  0                0                 0              1
# 775297                  0                0                 0              0
# 254331                  0                0                 0              0
#
#         conn_state_S1  conn_state_S2  conn_state_S3  conn_state_SF  \
# 954088              0              0              0              0
# 321061              0              0              0              0
# 9653                0              0              0              0
# 315841              0              0              0              0
# 772571              0              0              0              0
# ...               ...            ...            ...            ...
# 906056              0              0              0              0
# 237492              0              0              0              0
# 659883              0              0              0              0
# 775297              0              0              0              0
# 254331              0              0              0              0
#
#         conn_state_SH  conn_state_SHR
# 954088              0               0
# 321061              0               0
# 9653                0               0
# 315841              0               0
# 772571              0               0
# ...               ...             ...
# 906056              0               0
# 237492              0               0
# 659883              0               0
# 775297              0               0
# 254331              0               0
#
# [400000 rows x 25 columns]

# %%
df_test = df_c.sample(n = 5000, random_state = 1)
display(df_test)
df_test.to_csv('D:\SFU\\733-Lab\project\IoTScenarios\iot23_test.csv', index = None)
# Out:
#        duration orig_bytes resp_bytes  missed_bytes  orig_pkts  orig_ip_bytes  \
# 564555        0          0          0           0.0        1.0           40.0
# 778863        0          0          0           0.0        1.0           40.0
# 103241        0          0          0           0.0        1.0           40.0
# 740189        0          0          0           0.0        1.0           40.0
# 980373        0          0          0           0.0        1.0           40.0
# ...         ...        ...        ...           ...        ...            ...
# 436170        0          0          0           0.0        1.0           40.0
# 946423        0          0          0           0.0        1.0           60.0
# 26648         0          0          0           0.0        1.0           60.0
# 960682        0          0          0           0.0        0.0            0.0
# 289409        0          0          0           0.0        1.0           40.0
#
#         resp_pkts  resp_ip_bytes                      label  proto_icmp  \
# 564555        0.0            0.0                      Okiru           0
# 778863        0.0            0.0                      Okiru           0
# 103241        0.0            0.0                      Okiru           0
# 740189        0.0            0.0                      Okiru           0
# 980373        0.0            0.0  PartOfAHorizontalPortScan           0
# ...           ...            ...                        ...         ...
# 436170        0.0            0.0  PartOfAHorizontalPortScan           0
# 946423        0.0            0.0                     Benign           0
# 26648         0.0            0.0                     Benign           0
# 960682        0.0            0.0                       DDoS           0
# 289409        0.0            0.0                     Benign           0
#
#         proto_tcp  proto_udp  conn_state_OTH  conn_state_REJ  conn_state_RSTO  \
# 564555          1          0               0               0                0
# 778863          1          0               0               0                0
# 103241          1          0               0               0                0
# 740189          1          0               0               0                0
# 980373          1          0               0               0                0
# ...           ...        ...             ...             ...              ...
# 436170          1          0               0               0                0
# 946423          1          0               0               0                0
# 26648           1          0               0               0                0
# 960682          1          0               1               0                0
# 289409          1          0               0               0                0
#
#         conn_state_RSTOS0  conn_state_RSTR  conn_state_RSTRH  conn_state_S0  \
# 564555                  0                0                 0              1
# 778863                  0                0                 0              1
# 103241                  0                0                 0              1
# 740189                  0                0                 0              1
# 980373                  0                0                 0              1
# ...                   ...              ...               ...            ...
# 436170                  0                0                 0              1
# 946423                  0                0                 0              1
# 26648                   0                0                 0              1
# 960682                  0                0                 0              0
# 289409                  0                0                 0              1
#
#         conn_state_S1  conn_state_S2  conn_state_S3  conn_state_SF  \
# 564555              0              0              0              0
# 778863              0              0              0              0
# 103241              0              0              0              0
# 740189              0              0              0              0
# 980373              0              0              0              0
# ...               ...            ...            ...            ...
# 436170              0              0              0              0
# 946423              0              0              0              0
# 26648               0              0              0              0
# 960682              0              0              0              0
# 289409              0              0              0              0
#
#         conn_state_SH  conn_state_SHR
# 564555              0               0
# 778863              0               0
# 103241              0               0
# 740189              0               0
# 980373              0               0
# ...               ...             ...
# 436170              0               0
# 946423              0               0
# 26648               0               0
# 960682              0               0
# 289409              0               0
#
# [5000 rows x 25 columns]
